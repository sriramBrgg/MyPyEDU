# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Mukund94/Datasets/main/CardioGoodFitness-1.csv",sep=','
    )

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.shape
# Out:
# (180, 9)

# %%
df.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
sns.countplot(x='Product',data=df)
plt.show()

# %%
sns.countplot(x='Product',data=df,palette="Set1")
plt.show()

# %%
#Number of unique products?
df.Product.nunique()
# Out:
# 3

# %%
#Name of unique products?
df.Product.unique()
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %%
#Frequency of products?
df.Product.value_counts()
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %%
#How many products are there?
df.Product.shape[0]
# Out:
# 180

# %%
sns.countplot(x='Gender',data=df)
plt.show()

# %%
#Number of unique Gender?
df.Gender.nunique()
# Out:
# 2

# %%
#Genders?
df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
#Genders counts?
df.Gender.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
df.Gender.shape[0]
# Out:
# 180

# %%
df.hist(figsize=(10,10),color='k')
plt.show()

# %%
sns.distplot(df["Age"])
plt.show()

# %%
sns.boxplot(x=df["Age"],data=df,palette="Set3")
plt.show()

# %%
#Outlier calculation
Q3=33
Q1=24
IQR=Q3-Q1
IQR
# Out:
# 9

# %%
#Lower Outlier
Q1-1.5*IQR
# Out:
# 10.5

# %%
#Upper Outlier
Q3+1.5*IQR
# Out:
# 46.5

# %%
sns.countplot(x="Product",hue="Gender",data=df)
plt.show()

# %%
# Cross Tabs of Product and Gender
pd.crosstab(df['Product'],df['Gender'])
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
sns.countplot(x="Product",hue="MaritalStatus",data=df)
plt.show()

# %%
# Cross Tabs of Product and Marital Status
pd.crosstab(df['Product'],df['MaritalStatus'])
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
sns.boxplot(x="Product",y="Age",data=df,palette="Set3")
plt.show()

# %%
sns.boxplot(x="Product",y="Income",data=df)
plt.show()

# %%
sns.pairplot(data=df)
plt.show()

# %%
correlation=df.corr()
correlation
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(correlation,annot=True,)
# Out:
# <Axes: >
